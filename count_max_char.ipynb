# %%
x = input('Enter a String: ').lower()
max_ = 0
max_str = ""
for i in x:
    d = x.count(i)
    x = x.replace(i,'')
    print(d)
    if d % 2 == 1:
        print(i,'has odd frequency', )
    if d > max_:
        max_ = d
        max_str = i
    if d == max_:
        max_str += i
if len(max_str) == 1:
    print('The maximum frequency is:',max_,'and the character is: ',max_str)
elif len(max_str) > 1:
    print('The maximum frequency is: ',max_,'and the character are: ',max_str)
else:
    print('There is no maximum frequency')
# Out:
# Enter a String:  whatever(1877)
# 1
# w has odd frequency
# 1
# h has odd frequency
# 1
# a has odd frequency
# 1
# t has odd frequency
# 2
# 1
# v has odd frequency
# 0
# 1
# r has odd frequency
# 1
# ( has odd frequency
# 1
# 1 has odd frequency
# 1
# 8 has odd frequency
# 2
# 0
# 1
# ) has odd frequency
# The maximum frequency is:  2 and the character are:  ee7

# %%
x = input('Enter a String: ').lower()
char_counts = {}
for i in x:
    if i in char_counts:
        char_counts[i] += 1
    else:
        char_counts[i] = 1

max_frequency = 0
max_chars = ""
for char, frequency in char_counts.items():
    if frequency > max_frequency:
        max_frequency = frequency
        max_chars = char
    elif frequency == max_frequency:
        max_chars += char

if max_frequency == 0:
    print("There is no maximum frequency")
elif len(max_chars) == 1:
    print(f"The maximum frequency is: {max_frequency} and the character is: {max_chars}")
else:
    print(f"The maximum frequency is: {max_frequency} and the characters are: {max_chars}")
# Out:
# Enter a String:  whatever
# The maximum frequency is: 2 and the character is: e

# %%
x = input('Enter a word').lower()
char_counts = {}
for i in x:
    if i in char_counts:
        char_counts[i]+=1
    else:
        char_counts[i] = 1
    
max_frequency = 0
max_chars = ''

for char, frequency in char_counts.items():
    if frequency > max_frequency:
        max_frequency = frequency
        max_chars = char
    elif frequency == max_frequency:
        max_chars += char
    
if max_frequency == 0:
    print("There is no frequency")
elif len (max_chars) == 1:
    print(f"maximum frequency is: {max_frequency} and The char is: {max_chars}")
else:
    print(f"The maximum frequency is: {max_frequency} and the characters are: {max_chars}")
# Out:
# Enter a word whatever
# maximum frequency is: 2 and The char is: e

# %%
text = "Random text Generated by the author"
print(text[1:4])
# Out:
# and

# %%
text = "Dragons and cats"
'dragons' in text
# Out:
# False

# %%
text = 'There is a loku in the field'
new_text = text[:11]+'K'+text[12:]
print(new_text)
# Out:
# There is a Koku in the field

# %%
text = 'There is a loku in the field'
new_text = 'There is a koku in the field'
print(new_text)
# Out:
# There is a koku in the field
